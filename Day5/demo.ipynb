# %%
import pandas as pd

# %%
row1 = {
    'Subj': 'Henry',
    'isTreatment': False,
    'Time': 1,
    'Chan001': 4.3,
}
row

ser = pd.Series(row)
ser
# Out:
# Subj           Henry
# isTreatment    False
# Time               1
# Chan001          4.3
# dtype: object

# %%
url = "https://raw.githubusercontent.com/nickdelgrosso/CodeTeachingMaterials/main/datasets/MentalRotation.csv"
df = pd.read_csv(url)
df
# Out:
#       Subject  Trial  Angle  Matching Response  Time  Correct  Age Sex
# 0          49      1      0         0        n  3107        1   32   M
# 1          49      2    150         0        n  2930        1   32   M
# 2          49      3    150         1        b  1874        1   32   M
# 3          49      4    100         1        b  3793        1   32   M
# 4          49      5     50         1        b  2184        1   32   M
# ...       ...    ...    ...       ...      ...   ...      ...  ...  ..
# 5066       33     92    150         1        b  2095        1   20   F
# 5067       33     93    150         0        n  2125        1   20   F
# 5068       33     94     50         0        n  1226        1   20   F
# 5069       33     95    100         1        b  2783        1   20   F
# 5070       33     96      0         0        n  1017        1   20   F
#
# [5071 rows x 9 columns]

# %%
import numpy as np

# %%
np.median(df['Angle'])
# Out:
# np.float64(50.0)

# %%
df.loc[15:20]
# Out:
#     Subject  Trial  Angle  Matching Response  Time  Correct  Age Sex
# 15       49     16     50         1        b  1989        1   32   M
# 16       49     17    100         0        n  2144        1   32   M
# 17       49     18    150         1        b  3094        1   32   M
# 18       49     19     50         0        n  3388        1   32   M
# 19       49     20     50         1        b  1799        1   32   M
# 20       49     21    100         0        n  4289        1   32   M

# %%
df[['Correct', 'Angle']]
# Out:
#       Correct  Angle
# 0           1      0
# 1           1    150
# 2           1    150
# 3           1    100
# 4           1     50
# ...       ...    ...
# 5066        1    150
# 5067        1    150
# 5068        1     50
# 5069        1    100
# 5070        1      0
#
# [5071 rows x 2 columns]

# %%
df['Hello'] = df['Angle'] * 100
df['AA'] = 10
df
# Out:
#       Subject  Trial  Angle  Matching Response  Time  Correct  Age Sex  Hello  \
# 0          49      1      0         0        n  3107        1   32   M      0
# 1          49      2    150         0        n  2930        1   32   M  15000
# 2          49      3    150         1        b  1874        1   32   M  15000
# 3          49      4    100         1        b  3793        1   32   M  10000
# 4          49      5     50         1        b  2184        1   32   M   5000
# ...       ...    ...    ...       ...      ...   ...      ...  ...  ..    ...
# 5066       33     92    150         1        b  2095        1   20   F  15000
# 5067       33     93    150         0        n  2125        1   20   F  15000
# 5068       33     94     50         0        n  1226        1   20   F   5000
# 5069       33     95    100         1        b  2783        1   20   F  10000
# 5070       33     96      0         0        n  1017        1   20   F      0
#
#       AA
# 0     10
# 1     10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5071 entries, 0 to 5070
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Subject   5071 non-null   int64
#  1   Trial     5071 non-null   int64
#  2   Angle     5071 non-null   int64
#  3   Matching  5071 non-null   int64
#  4   Response  5071 non-null   object
#  5   Time      5071 non-null   int64
#  6   Correct   5071 non-null   int64
#  7   Age       5071 non-null   int64
#  8   Sex       5071 non-null   object
#  9   Hello     5071 non-null   int64
#  10  AA        5071 non-null   int64
# dtypes: int64(9), object(2)
# memory usage: 435.9+ KB

# %%
df.describe()
# Out:
#            Subject        Trial        Angle     Matching         Time  \
# count  5071.000000  5071.000000  5071.000000  5071.000000  5071.000000
# mean     27.489253    48.775192    74.640110     0.500690  2732.093275
# std      15.600973    27.653790    55.857522     0.500049  1413.906647
# min       1.000000     1.000000     0.000000     0.000000   705.000000
# 25%      14.000000    25.000000     0.000000     0.000000  1639.500000
# 50%      28.000000    49.000000    50.000000     1.000000  2402.000000
# 75%      41.000000    73.000000   100.000000     1.000000  3498.000000
# max      54.000000    96.000000   150.000000     1.000000  7466.000000
#
#            Correct         Age         Hello      AA
# count  5071.000000  5071.00000   5071.000000  5071.0
# mean      0.904555    22.31197   7464.011043    10.0
# std       0.293857     3.99942   5585.752198     0.0
# min       0.000000    18.00000      0.000000    10.0
# 25%       1.000000    19.00000      0.000000    10.0
# ...

# %%
df.plot.scatter(x='Trial', y='Time')
# Out:
# <Axes: xlabel='Trial', ylabel='Time'>

# %%
male_mean_time = df[df['Sex'] == 'M'].Time.mean()
female_mean_time = df[df['Sex'] == 'F'].Time.mean()
male_mean_time, female_mean_time
# Out:
# (np.float64(2502.790055248619), np.float64(2903.8927216281477))

# %%
df.groupby('Sex').Time.mean().reset_index()
# Out:
#   Sex         Time
# 0   F  2903.892722
# 1   M  2502.790055

# %%
df.groupby(['Sex', 'Angle']).Time.mean()
# Out:
# Sex  Angle
# F    0        2026.559184
#      50       2735.323810
#      100      3365.643950
#      150      3519.018310
# M    0        1851.851577
#      50       2328.174312
#      100      2836.771218
#      150      2988.144689
# Name: Time, dtype: float64

# %%
import seaborn as sns

# %%
sns.catplot(data=df, x='Angle', y='Time', hue='Sex', kind='point')

# %%
from scipy import sparse

# %%
arr = np.zeros((10, 10), dtype=np.uint8)

# %%
from random import random

# %%
class DataFrame:

    def __init__(self):
        self.time = 3
        self.name = 'Nick'

    def _repr_html_(self):
        return "<h1>Hi</h1><p>Isn't this neat?</p>"

    @property
    def mean(self):
        return random()


df = DataFrame()
df.name
df
# Out:
# <h1>Hi</h1><p>Isn't this neat?</p>

# %%
df = pd.DataFrame()
df['name'] = ['Alisson', 'Man Yung', 'Nikolas', 'Nick']
# df['funs'] = [np.mean, np.min, np.median, np.max]
df.convert_dtypes()
# Out:
#        name
# 0   Alisson
# 1  Man Yung
# 2   Nikolas
# 3      Nick
